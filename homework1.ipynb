# %% [markdown]
# <a href="https://colab.research.google.com/github/gferew1/IntroML/blob/main/homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount ('/content/drive')

file_path = '/content/drive/My Drive/Colab Notebooks/D3.csv'

df = pd.read_csv(file_path)

#display the fisr 5 rows of the DataFrame
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %%
#seperate features and labels
X0 = df.values[:,0] # get input values from first column -- X is a list here
y = df.values[:,3] # get output values from second column- Y is the list here
m = len(y) #number of training examples
n = len(X0) #number of training examples

plt.scatter(X0, y, color ='red', marker = '+')

plt.show()

# %%
X_0 = np.ones((m, 1))
X_0[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X_1 = X0.reshape(m, 1)
X_1[:10]
# Out:
# array([[0.        ],
#        [0.04040404],
#        [0.08080808],
#        [0.12121212],
#        [0.16161616],
#        [0.2020202 ],
#        [0.24242424],
#        [0.28282828],
#        [0.32323232],
#        [0.36363636]])

# %%
# Lets use hstack() function from numpy to stack X_0 and X_1 horizontally (i.e. column
# This will be our final X matrix (feature matrix)
X = np.hstack((X_0, X_1))
X[:5]
# Out:
# array([[1.        , 0.        ],
#        [1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616]])

# %%
theta = np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
def compute_cost(X, y, theta):

    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

# %%
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
def gradient_descent(X, y, theta, alpha, iterations):


    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# %%
theta = [0., 0.]
iterations = 2500
alpha = 0.02

# %%
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 5.71850653 -1.9568206 ]
# cost_history = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
plt.scatter(X[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
#seperate features and labels
X1 = df.values[:,1] # get input values from first column -- X is a list here
y = df.values[:,3] # get output values from second column- Y is the list here
m = len(y) #number of training examples
n = len(X1) #number of training examples

plt.scatter(X1, y, color ='brown', marker = '+')

plt.show()

# %%
#seperate features and labels
X2 = df.values[:,2] # get input values from first column -- X is a list here
y = df.values[:,3] # get output values from second column- Y is the list here
m = len(y) #number of training examples
n = len(X2) #number of training examples

plt.scatter(X2, y, color ='purple', marker = '+')

plt.show()

# %%
X_2 = X1.reshape(m, 1) # reshape to M
X_2[:10] #
# Out:
# array([[3.44      ],
#        [0.1349495 ],
#        [0.82989899],
#        [1.52484848],
#        [2.21979798],
#        [2.91474747],
#        [3.60969697],
#        [0.30464646],
#        [0.99959596],
#        [1.69454546]])

# %%
X1 = np.hstack((X_0, X_2))
X1[:5]
# Out:
# array([[1.        , 3.44      ],
#        [1.        , 0.1349495 ],
#        [1.        , 0.82989899],
#        [1.        , 1.52484848],
#        [1.        , 2.21979798]])

# %%
theta = np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
cost = compute_cost(X1, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
theta_2 = [0., 0.]
iterations_2 = 2500
alpha_2 = 0.02

# %%
theta, cost_history = gradient_descent(X1, y, theta_2, alpha_2, iterations_2)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 2.87138807 -0.52046942]
# cost_history = [5.29785963 5.12026797 4.98070413 ... 3.62945112 3.62945112 3.62945112]

# %%
plt.scatter(X1[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X1[:, 1], X1.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s') #dscs
plt.ylabel('Profit in $10,000s') #
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(range(1, iterations_2 + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
X_3 = X2.reshape(m, 1) # reshape to M
X_3[:10] #
# Out:
# array([[0.44      ],
#        [0.88848485],
#        [1.3369697 ],
#        [1.78545454],
#        [2.23393939],
#        [2.68242424],
#        [3.13090909],
#        [3.57939394],
#        [0.02787879],
#        [0.47636364]])

# %%
X2 = np.hstack((X_0, X_3))
X2[:5]
# Out:
# array([[1.        , 0.44      ],
#        [1.        , 0.88848485],
#        [1.        , 1.3369697 ],
#        [1.        , 1.78545454],
#        [1.        , 2.23393939]])

# %%
theta = np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
cost = compute_cost(X2, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
theta_3 = [0., 0.]
iterations_3 = 2500
alpha_3 = 0.02

# %%
theta, cost_history = gradient_descent(X2, y, theta_3, alpha_3, iterations_3)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 2.87138807 -0.52046942]
# cost_history = [5.29785963 5.12026797 4.98070413 ... 3.62945112 3.62945112 3.62945112]

# %%
plt.scatter(X2[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X2[:, 1], X2.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s') #dscs
plt.ylabel('Profit in $10,000s') #
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(range(1, iterations_3 + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
#seperate features and labels
X = df.values[:,(0,1,2)] # get input values from first column -- X is a list here
y = df.values[:,3] # get output values from second column- Y is the list here
m = len(y) #number of training examples
n = len(X) #number of training examples

# %%
X_n = X.reshape(m, 3) # reshape to M
X_n[:10] #
# Out:
# array([[0.        , 3.44      , 0.44      ],
#        [0.04040404, 0.1349495 , 0.88848485],
#        [0.08080808, 0.82989899, 1.3369697 ],
#        [0.12121212, 1.52484848, 1.78545454],
#        [0.16161616, 2.21979798, 2.23393939],
#        [0.2020202 , 2.91474747, 2.68242424],
#        [0.24242424, 3.60969697, 3.13090909],
#        [0.28282828, 0.30464646, 3.57939394],
#        [0.32323232, 0.99959596, 0.02787879],
#        [0.36363636, 1.69454546, 0.47636364]])

# %%
X = np.hstack((X_0, X_n))
X[:5]
# Out:
# array([[1.        , 0.        , 3.44      , 0.44      ],
#        [1.        , 0.04040404, 0.1349495 , 0.88848485],
#        [1.        , 0.08080808, 0.82989899, 1.3369697 ],
#        [1.        , 0.12121212, 1.52484848, 1.78545454],
#        [1.        , 0.16161616, 2.21979798, 2.23393939]])

# %%
theta = np.zeros(4)
theta
# Out:
# array([0., 0., 0., 0.])

# %%
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
theta_n = [0., 0.,0.,0.]
iterations_n = 2500
alpha_n = 0.02

# %%
theta, cost_history = gradient_descent(X, y, theta_n, alpha_n, iterations_n)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 5.27880642 -1.99872398  0.53840648 -0.2604187 ]
# cost_history = [4.9441034  4.58765223 4.34920128 ... 0.73853138 0.73853111 0.73853085]

# %%
plt.scatter(X[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X[:, 1], X.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s') #dscs
plt.ylabel('Profit in $10,000s') #
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(range(1, iterations_n + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

# %%
#2.4
sum0= theta[0]+theta[1]*(1)+theta[2]*(1)+theta[3]*(1)
sum1= theta[0]+theta[1]*(2)+theta[2]*(0)+theta[3]*(4)
sum2= theta[0]+theta[1]*(3)+theta[2]*(2)+theta[3]*(1)

# %%
print(sum0)
print(sum1)
print(sum2)
# Out:
# 3.5580702275511404
# 0.2396836741745021
# 0.09902875352867041
